# %% [markdown]
# Step1:- Importing the all the neccessary Libraries That will be Used in this Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print("All Libraries are Imported")
# Out:
# All Libraries are Imported

# %% [markdown]
# <p>Importing the Dataset of the BhartiAirtel

# %%
df=pd.read_csv("BHARTIARTL.csv")
df.head()
# Out:
#          Date  Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# 0  2002-02-18  BHARTI     EQ        0.00  51.90  51.90  43.50  44.70  44.35
# 1  2002-02-19  BHARTI     EQ       44.35  45.15  45.15  41.30  41.35  41.70
# 2  2002-02-20  BHARTI     EQ       41.70  40.60  42.80  40.25  41.20  41.25
# 3  2002-02-21  BHARTI     EQ       41.25  42.85  43.40  42.15  42.20  42.40
# 4  2002-02-22  BHARTI     EQ       42.40  42.65  43.60  41.10  43.35  43.30
#
#     VWAP    Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  46.00  10381190  4.775431e+13     NaN           6503775.0       0.6265
# 1  42.58   3552660  1.512609e+13     NaN           1741184.0       0.4901
# 2  41.56   2512964  1.044348e+13     NaN                 NaN          NaN
# 3  42.76   1338196  5.722681e+12     NaN            485969.0       0.3632
# 4  42.75    811327  3.468413e+12     NaN            399133.0       0.4920

# %% [markdown]
# Analysing the Dataset
# 1. Stastical Analysis of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4774 entries, 0 to 4773
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4774 non-null   object
#  1   Symbol              4774 non-null   object
#  2   Series              4774 non-null   object
#  3   Prev Close          4774 non-null   float64
#  4   Open                4774 non-null   float64
#  5   High                4774 non-null   float64
#  6   Low                 4774 non-null   float64
#  7   Last                4774 non-null   float64
#  8   Close               4774 non-null   float64
#  9   VWAP                4774 non-null   float64
#  10  Volume              4774 non-null   int64
#  11  Turnover            4774 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4758 non-null   float64
#  14  %Deliverble         4758 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 559.6+ KB

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4774.000000  4774.000000  4774.000000  4774.000000  4774.000000
# mean    379.688333   380.478456   387.034761   372.705216   379.798502
# std     207.237329   207.774041   212.037403   202.270599   207.163319
# min       0.000000    21.100000    21.600000    20.650000    20.700000
# 25%     301.325000   302.000000   306.825000   296.575000   301.162500
# 50%     348.800000   349.000000   353.925000   343.500000   348.575000
# 75%     423.850000   425.000000   431.312500   417.250000   423.275000
# max    1125.650000  1133.900000  1184.200000  1090.250000  1131.350000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  4774.000000  4774.000000  4.774000e+03  4.774000e+03    2456.000000
# mean    379.800765   379.824874  5.341070e+06  2.245218e+14   85133.370114
# std     207.176886   206.953021  7.976471e+06  4.014405e+14   75136.125261
# min      20.750000    20.960000  2.824600e+04  7.373966e+10    1392.000000
# 25%     301.400000   301.390000  1.838864e+06  5.580891e+13   43331.000000
# 50%     348.800000   348.750000  3.474614e+06  1.268449e+14   62231.500000
# 75%     423.937500   424.297500  5.922892e+06  2.382761e+14   97361.750000
# max    1125.650000  1113.580000  1.948880e+08  1.090756e+16  946705.000000
#
#        Deliverable Volume  %Deliverble
# count        4.758000e+03  4758.000000
# mean         2.653730e+06     0.521711
# std          4.016530e+06     0.148377
# min          1.830100e+04     0.071900
# 25%          8.125398e+05     0.417850
# 50%          1.793994e+06     0.530000
# 75%          3.254393e+06     0.628475
# max          1.229199e+08     0.999800

# %% [markdown]
# #### Finding the Null Values in The Dataset

# %%
df.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2318
# Deliverable Volume      16
# %Deliverble             16
# dtype: int64

# %%
df.size
# Out:
# 71610

# %% [markdown]
# <p> Removing the null values

# %%
df2=df.dropna()

# %%
df2.head()
# Out:
#             Date      Symbol Series  Prev Close    Open    High     Low  \
# 2318  2011-06-01  BHARTIARTL     EQ      374.15  375.25  384.65  375.00
# 2319  2011-06-02  BHARTIARTL     EQ      381.60  379.00  385.90  378.50
# 2320  2011-06-03  BHARTIARTL     EQ      381.15  382.00  384.60  377.15
# 2321  2011-06-06  BHARTIARTL     EQ      378.45  380.35  382.60  375.50
# 2322  2011-06-07  BHARTIARTL     EQ      380.00  379.00  381.85  377.00
#
#         Last   Close    VWAP   Volume      Turnover   Trades  \
# 2318  381.75  381.60  381.07  4153497  1.582781e+14  47549.0
# 2319  381.05  381.15  382.61  2037011  7.793876e+13  29176.0
# 2320  379.30  378.45  381.20  2443813  9.315705e+13  26544.0
# 2321  380.05  380.00  380.05  2540466  9.655161e+13  24197.0
# 2322  378.45  377.85  379.53  1980997  7.518469e+13  17995.0
#
#       Deliverable Volume  %Deliverble
# 2318           2387047.0       0.5747
# 2319           1064294.0       0.5225
# 2320           1594229.0       0.6524
# 2321           1733467.0       0.6823
# 2322           1267789.0       0.6400

# %%
df2.isna().sum()
# Out:
# Date                  0
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
df2.head()
# Out:
#             Date      Symbol Series  Prev Close    Open    High     Low  \
# 2318  2011-06-01  BHARTIARTL     EQ      374.15  375.25  384.65  375.00
# 2319  2011-06-02  BHARTIARTL     EQ      381.60  379.00  385.90  378.50
# 2320  2011-06-03  BHARTIARTL     EQ      381.15  382.00  384.60  377.15
# 2321  2011-06-06  BHARTIARTL     EQ      378.45  380.35  382.60  375.50
# 2322  2011-06-07  BHARTIARTL     EQ      380.00  379.00  381.85  377.00
#
#         Last   Close    VWAP   Volume      Turnover   Trades  \
# 2318  381.75  381.60  381.07  4153497  1.582781e+14  47549.0
# 2319  381.05  381.15  382.61  2037011  7.793876e+13  29176.0
# 2320  379.30  378.45  381.20  2443813  9.315705e+13  26544.0
# 2321  380.05  380.00  380.05  2540466  9.655161e+13  24197.0
# 2322  378.45  377.85  379.53  1980997  7.518469e+13  17995.0
#
#       Deliverable Volume  %Deliverble
# 2318           2387047.0       0.5747
# 2319           1064294.0       0.5225
# 2320           1594229.0       0.6524
# 2321           1733467.0       0.6823
# 2322           1267789.0       0.6400

# %%
print(df2["High"].max())
print(df2.High.min())
# Out:
# 623.0
# 243.85

# %%
print(df2.Turnover.max())
print(df2.Turnover.min())
# Out:
# 1.0907564462725e+16
# 2189775000000.0

# %% [markdown]
# #### Finding All the Maximum and Minimum Values in the Dataset From Each Column

# %%
print(df2.min())
# Out:
# Date                       2011-06-01
# Symbol                     BHARTIARTL
# Series                             EQ
# Prev Close                      242.3
# Open                            240.0
# High                           243.85
# Low                             215.8
# Last                            241.1
# Close                           242.3
# VWAP                           241.61
# Volume                          71097
# Turnover              2189775000000.0
# Trades                         1392.0
# Deliverable Volume            18301.0
# %Deliverble                    0.0719
# dtype: object

# %%
print(df2.max())
# Out:
# Date                           2021-04-30
# Symbol                         BHARTIARTL
# Series                                 EQ
# Prev Close                         608.85
# Open                                614.9
# High                                623.0
# Low                                599.45
# Last                                611.9
# Close                              608.85
# VWAP                               613.31
# Volume                          194887984
# Turnover              10907564462725000.0
# Trades                           946705.0
# Deliverable Volume            122919948.0
# %Deliverble                        0.9263
# dtype: object

# %%
df.head()
# Out:
#          Date  Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# 0  2002-02-18  BHARTI     EQ        0.00  51.90  51.90  43.50  44.70  44.35
# 1  2002-02-19  BHARTI     EQ       44.35  45.15  45.15  41.30  41.35  41.70
# 2  2002-02-20  BHARTI     EQ       41.70  40.60  42.80  40.25  41.20  41.25
# 3  2002-02-21  BHARTI     EQ       41.25  42.85  43.40  42.15  42.20  42.40
# 4  2002-02-22  BHARTI     EQ       42.40  42.65  43.60  41.10  43.35  43.30
#
#     VWAP    Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  46.00  10381190  4.775431e+13     NaN           6503775.0       0.6265
# 1  42.58   3552660  1.512609e+13     NaN           1741184.0       0.4901
# 2  41.56   2512964  1.044348e+13     NaN                 NaN          NaN
# 3  42.76   1338196  5.722681e+12     NaN            485969.0       0.3632
# 4  42.75    811327  3.468413e+12     NaN            399133.0       0.4920

# %%
print(df2.Date.dtype)
# Out:
# object

# %% [markdown]
# Converting the Date Column From Object Data type to datetime data type beacuse we cannot train the model with object data type

# %%
# df2["Date"]=pd.to_datetime(df2["Date"])
# df2.sort_values("Date",inplace=True)
# df2.set_index("Date",inplace=True)

# this cell will run only at one time

# %%
df2.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                float64
# Deliverable Volume    float64
# %Deliverble           float64
# dtype: object

# %%
df2.head()
# Out:
#             Date      Symbol Series  Prev Close    Open    High     Low  \
# 2318  2011-06-01  BHARTIARTL     EQ      374.15  375.25  384.65  375.00
# 2319  2011-06-02  BHARTIARTL     EQ      381.60  379.00  385.90  378.50
# 2320  2011-06-03  BHARTIARTL     EQ      381.15  382.00  384.60  377.15
# 2321  2011-06-06  BHARTIARTL     EQ      378.45  380.35  382.60  375.50
# 2322  2011-06-07  BHARTIARTL     EQ      380.00  379.00  381.85  377.00
#
#         Last   Close    VWAP   Volume      Turnover   Trades  \
# 2318  381.75  381.60  381.07  4153497  1.582781e+14  47549.0
# 2319  381.05  381.15  382.61  2037011  7.793876e+13  29176.0
# 2320  379.30  378.45  381.20  2443813  9.315705e+13  26544.0
# 2321  380.05  380.00  380.05  2540466  9.655161e+13  24197.0
# 2322  378.45  377.85  379.53  1980997  7.518469e+13  17995.0
#
#       Deliverable Volume  %Deliverble
# 2318           2387047.0       0.5747
# 2319           1064294.0       0.5225
# 2320           1594229.0       0.6524
# 2321           1733467.0       0.6823
# 2322           1267789.0       0.6400

# %% [markdown]
# 2. Analysing The Dataset Through Visual Representation

# %% [markdown]
# #### Analysing the Close Price Column

# %%
plt.figure(figsize=(12,7))
plt.plot(df2["Close"],label="Closing Price of BhartiAirtel")
plt.title("Closing Price of the Stock of the Bharti Airte over Years")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.plot(df["Close"],label="Closing Price of BhartiAirtel")
plt.title("Closing Price of the Stock of the Bharti Airte over Years")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.set_index("Date",inplace=True)

# %%
df.head()
# Out:
#             Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# Date
# 2002-02-18  BHARTI     EQ        0.00  51.90  51.90  43.50  44.70  44.35
# 2002-02-19  BHARTI     EQ       44.35  45.15  45.15  41.30  41.35  41.70
# 2002-02-20  BHARTI     EQ       41.70  40.60  42.80  40.25  41.20  41.25
# 2002-02-21  BHARTI     EQ       41.25  42.85  43.40  42.15  42.20  42.40
# 2002-02-22  BHARTI     EQ       42.40  42.65  43.60  41.10  43.35  43.30
#
#              VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2002-02-18  46.00  10381190  4.775431e+13     NaN           6503775.0
# 2002-02-19  42.58   3552660  1.512609e+13     NaN           1741184.0
# 2002-02-20  41.56   2512964  1.044348e+13     NaN                 NaN
# 2002-02-21  42.76   1338196  5.722681e+12     NaN            485969.0
# 2002-02-22  42.75    811327  3.468413e+12     NaN            399133.0
#
#             %Deliverble
# Date
# 2002-02-18       0.6265
# 2002-02-19       0.4901
# 2002-02-20          NaN
# 2002-02-21       0.3632
# 2002-02-22       0.4920

# %% [markdown]
# <p> Using a Different Approach To understand the dataset

# %%
df.dropna(inplace=True)

# %%
plt.figure(figsize=(12,7))
plt.plot(df["Close"],label="Closing Price of Bharti Airtel")
plt.plot()
# Out:
# []

# %%
df2.head()
# Out:
#             Date      Symbol Series  Prev Close    Open    High     Low  \
# 2318  2011-06-01  BHARTIARTL     EQ      374.15  375.25  384.65  375.00
# 2319  2011-06-02  BHARTIARTL     EQ      381.60  379.00  385.90  378.50
# 2320  2011-06-03  BHARTIARTL     EQ      381.15  382.00  384.60  377.15
# 2321  2011-06-06  BHARTIARTL     EQ      378.45  380.35  382.60  375.50
# 2322  2011-06-07  BHARTIARTL     EQ      380.00  379.00  381.85  377.00
#
#         Last   Close    VWAP   Volume      Turnover   Trades  \
# 2318  381.75  381.60  381.07  4153497  1.582781e+14  47549.0
# 2319  381.05  381.15  382.61  2037011  7.793876e+13  29176.0
# 2320  379.30  378.45  381.20  2443813  9.315705e+13  26544.0
# 2321  380.05  380.00  380.05  2540466  9.655161e+13  24197.0
# 2322  378.45  377.85  379.53  1980997  7.518469e+13  17995.0
#
#       Deliverable Volume  %Deliverble
# 2318           2387047.0       0.5747
# 2319           1064294.0       0.5225
# 2320           1594229.0       0.6524
# 2321           1733467.0       0.6823
# 2322           1267789.0       0.6400

# %% [markdown]
# Creating Heatmap to analyse the Dataset in more easy way

# %% [markdown]
# <p> Befor Creating the Heatmap Visuals we need to convert all the string data types into int or numeric
# or we can drop them . Because Heatmap is only created for the numeric column it cannot be created for the strig

# %%
df3=df2.drop(["Symbol","Series","Turnover","Trades"],axis="columns")

# %%
plt.figure(figsize=(9,6))
sns.heatmap(df3.corr(),annot=True,cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 plt.figure(figsize=(9,6))
# ----> 2 sns.heatmap(df3.corr(),annot=True,cmap='coolwarm')
#       3 plt.title("Correlation Heatmap")
#       4 plt.show()
#
# File c:\Users\codin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\codin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\codin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\codin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '2011-06-01'

# %% [markdown]
# The Column We Required to Predict the Price of the Stock are as follows:-
#
# 1. open
# 2. High
# 3. Low
# 4. Close
# 5. Volumn
# 6. Close_1
# 7. High_Low_Spread
# 8. Return
# 9. SMA_5
# 10. SMA_10

# %% [markdown]
# Detecting the Outliers in the dataset by uisng the Box Plot

# %%
df3.head()
# Out:
#             Date  Prev Close    Open    High     Low    Last   Close    VWAP  \
# 2318  2011-06-01      374.15  375.25  384.65  375.00  381.75  381.60  381.07
# 2319  2011-06-02      381.60  379.00  385.90  378.50  381.05  381.15  382.61
# 2320  2011-06-03      381.15  382.00  384.60  377.15  379.30  378.45  381.20
# 2321  2011-06-06      378.45  380.35  382.60  375.50  380.05  380.00  380.05
# 2322  2011-06-07      380.00  379.00  381.85  377.00  378.45  377.85  379.53
#
#        Volume  Deliverable Volume  %Deliverble
# 2318  4153497           2387047.0       0.5747
# 2319  2037011           1064294.0       0.5225
# 2320  2443813           1594229.0       0.6524
# 2321  2540466           1733467.0       0.6823
# 2322  1980997           1267789.0       0.6400

# %%
df4=df3.drop(["Prev Close","VWAP","Deliverable Volume"],axis="columns")

# %%
df4.head()
# Out:
#             Date    Open    High     Low    Last   Close   Volume  %Deliverble
# 2318  2011-06-01  375.25  384.65  375.00  381.75  381.60  4153497       0.5747
# 2319  2011-06-02  379.00  385.90  378.50  381.05  381.15  2037011       0.5225
# 2320  2011-06-03  382.00  384.60  377.15  379.30  378.45  2443813       0.6524
# 2321  2011-06-06  380.35  382.60  375.50  380.05  380.00  2540466       0.6823
# 2322  2011-06-07  379.00  381.85  377.00  378.45  377.85  1980997       0.6400

# %%
Box_columns=["Open","High","Low","Close","Volume"]
for i in Box_columns:
    plt.figure(figsize=(9,6))
    sns.boxplot(df4[i])
    plt.title("Box Plot For Outliers Detection in {} column".format(i))
    plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# plt.figure(figsize=(10, 6))
# sns.boxplot(data=df4[['Open', 'High', 'Low', 'Close']])
# plt.title('Box Plot for Outlier Detection')
# plt.show()

# %% [markdown]
# ### From The Above visuals We can Clearly see that there are outliers in the dataset. so weed to fix them before Training our model because it can create the misconseption for our model in training

# %%
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    return data[(data[column] < lower_limit) | (data[column] > upper_limit)]

# %%
outliers = detect_outliers_iqr(df4, 'Close')
print(f"Total Outliers in Close Price: {len(outliers)}")
# Out:
# Total Outliers in Close Price: 176

# %%
def replace_outliers_with_median(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    median = data[column].median()
    
    data[column] = data[column].apply(lambda x: median if x < lower_limit or x > upper_limit else x)
    return data

# %%
df4.head()
# Out:
#             Date    Open    High     Low    Last   Close   Volume  %Deliverble
# 2318  2011-06-01  375.25  384.65  375.00  381.75  381.60  4153497       0.5747
# 2319  2011-06-02  379.00  385.90  378.50  381.05  381.15  2037011       0.5225
# 2320  2011-06-03  382.00  384.60  377.15  379.30  378.45  2443813       0.6524
# 2321  2011-06-06  380.35  382.60  375.50  380.05  380.00  2540466       0.6823
# 2322  2011-06-07  379.00  381.85  377.00  378.45  377.85  1980997       0.6400

# %%
df4 = replace_outliers_with_median(df4, 'Close')

# %%
df4=replace_outliers_with_median(df4,"Open")

# %%
df4=replace_outliers_with_median(df4,"High")

# %%
df4=replace_outliers_with_median(df4,"Volume")

# %%
outliers = detect_outliers_iqr(df4, 'Close')
print(f"Total Outliers in Close Price: {len(outliers)}")
# Out:
# Total Outliers in Close Price: 143

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df4["Close"])
plt.title("Updated Box plot after Removing the Outliers")
plt.show()

# %%
df5=df3.copy()

# %%
df5.head()
# Out:
#             Date  Prev Close    Open    High     Low    Last   Close    VWAP  \
# 2318  2011-06-01      374.15  375.25  384.65  375.00  381.75  381.60  381.07
# 2319  2011-06-02      381.60  379.00  385.90  378.50  381.05  381.15  382.61
# 2320  2011-06-03      381.15  382.00  384.60  377.15  379.30  378.45  381.20
# 2321  2011-06-06      378.45  380.35  382.60  375.50  380.05  380.00  380.05
# 2322  2011-06-07      380.00  379.00  381.85  377.00  378.45  377.85  379.53
#
#        Volume  Deliverable Volume  %Deliverble
# 2318  4153497           2387047.0       0.5747
# 2319  2037011           1064294.0       0.5225
# 2320  2443813           1594229.0       0.6524
# 2321  2540466           1733467.0       0.6823
# 2322  1980997           1267789.0       0.6400

# %%
df5.drop(["Prev Close","Last","VWAP","Deliverable Volume","%Deliverble"],axis="columns",inplace=True)

# %%
outliers = detect_outliers_iqr(df5, 'Close')
print(f"Total Outliers in Close Price: {len(outliers)}")
# Out:
# Total Outliers in Close Price: 176

# %%
def replace_outliers_with_median(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    median = data[column].median()
    
    data[column] = data[column].apply(lambda x: median if x < lower_limit or x > upper_limit else x)
    return data

# %%
df5 = replace_outliers_with_median(df5, 'Close')

# %%
df5=replace_outliers_with_median(df5,"Open")

# %%
df5=replace_outliers_with_median(df5,"High")

# %%
df5=replace_outliers_with_median(df5,"Volume")

# %%
plt.figure(figsize=(8,7))
sns.boxplot(data=df5[["Open","High","Low","Close"]])
plt.title("Updated Box Plot after Outliers Removing")
plt.show()

# %%
outliers = detect_outliers_iqr(df5, 'Close')
print(f"Total Outliers in Close Price: {len(outliers)}")
# Out:
# Total Outliers in Close Price: 143

# %%
df5.head()
# Out:
#             Date    Open    High     Low   Close     Volume
# 2318  2011-06-01  375.25  384.65  375.00  381.60  4153497.0
# 2319  2011-06-02  379.00  385.90  378.50  381.15  2037011.0
# 2320  2011-06-03  382.00  384.60  377.15  378.45  2443813.0
# 2321  2011-06-06  380.35  382.60  375.50  380.00  2540466.0
# 2322  2011-06-07  379.00  381.85  377.00  377.85  1980997.0

# %%
df5.shape
# Out:
# (2456, 6)

# %%
df5
# Out:
#             Date    Open    High     Low    Close      Volume
# 2318  2011-06-01  375.25  384.65  375.00  381.600   4153497.0
# 2319  2011-06-02  379.00  385.90  378.50  381.150   2037011.0
# 2320  2011-06-03  382.00  384.60  377.15  378.450   2443813.0
# 2321  2011-06-06  380.35  382.60  375.50  380.000   2540466.0
# 2322  2011-06-07  379.00  381.85  377.00  377.850   1980997.0
# ...          ...     ...     ...     ...      ...         ...
# 4769  2021-04-26  522.75  528.50  522.75  355.375   5819893.0
# 4770  2021-04-27  355.50  361.55  526.25  355.375   9693047.0
# 4771  2021-04-28  355.50  361.55  535.60  355.375  11970652.0
# 4772  2021-04-29  355.50  361.55  539.10  355.375   8683857.0
# 4773  2021-04-30  355.50  361.55  533.50  355.375   8178192.0
#
# [2456 rows x 6 columns]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df5[["Open","High","Low","Volume"]])
plt.title("Box Plot For Outliers Detection")
plt.show()

# %%
df5.head()
# Out:
#             Date    Open    High     Low   Close     Volume
# 2318  2011-06-01  375.25  384.65  375.00  381.60  4153497.0
# 2319  2011-06-02  379.00  385.90  378.50  381.15  2037011.0
# 2320  2011-06-03  382.00  384.60  377.15  378.45  2443813.0
# 2321  2011-06-06  380.35  382.60  375.50  380.00  2540466.0
# 2322  2011-06-07  379.00  381.85  377.00  377.85  1980997.0

# %%
df5["Close_1"]=df5['Close'].shift(1)

# %%
df5["High_Low_Spread"]=df5["High"]-df5["Low"]

# %%
df5["Return"]=(df5["Close"]-df5['Close_1'])/ df5['Close_1']

# %%
df5.head()
# Out:
#             Date    Open    High     Low   Close     Volume  Close_1  \
# 2327  2011-06-14  377.95  380.50  377.00  379.30  2879443.0   377.60
# 2328  2011-06-15  377.95  379.40  375.10  376.75  2319378.0   379.30
# 2329  2011-06-16  375.00  379.80  367.65  369.65  5402846.0   376.75
# 2330  2011-06-17  369.20  381.95  369.20  380.55  4624129.0   369.65
# 2331  2011-06-20  380.00  391.95  375.55  389.85  7974447.0   380.55
#
#         Return   SMA_5   SMA_10  High_Low_Spread
# 2327  0.004502  377.03  378.420             3.50
# 2328 -0.006723  376.83  377.935             4.30
# 2329 -0.018845  375.45  376.785            12.15
# 2330  0.029487  376.77  376.995            12.75
# 2331  0.024438  379.22  377.980            16.40

# %%
df5.isna().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# Close_1    1
# Return     1
# dtype: int64

# %%
df5.shape
# Out:
# (2456, 8)

# %%
df5['SMA_5'] = df5['Close'].rolling(window=5).mean()
df5['SMA_10'] = df5['Close'].rolling(window=10).mean()

# %%
df5.head()
# Out:
#             Date    Open    High     Low   Close     Volume  Close_1  \
# 2318  2011-06-01  375.25  384.65  375.00  381.60  4153497.0      NaN
# 2319  2011-06-02  379.00  385.90  378.50  381.15  2037011.0   381.60
# 2320  2011-06-03  382.00  384.60  377.15  378.45  2443813.0   381.15
# 2321  2011-06-06  380.35  382.60  375.50  380.00  2540466.0   378.45
# 2322  2011-06-07  379.00  381.85  377.00  377.85  1980997.0   380.00
#
#         Return   SMA_5  SMA_10
# 2318       NaN     NaN     NaN
# 2319 -0.001179     NaN     NaN
# 2320 -0.007084     NaN     NaN
# 2321  0.004096     NaN     NaN
# 2322 -0.005658  379.81     NaN

# %%
df5.shape
# Out:
# (2456, 10)

# %%
df5.isna().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# Close_1    0
# Return     0
# SMA_5      0
# SMA_10     0
# dtype: int64

# %%
df5.dropna(inplace=True)

# %%
df5.head()
# Out:
#             Date    Open    High     Low   Close     Volume  Close_1  \
# 2327  2011-06-14  377.95  380.50  377.00  379.30  2879443.0   377.60
# 2328  2011-06-15  377.95  379.40  375.10  376.75  2319378.0   379.30
# 2329  2011-06-16  375.00  379.80  367.65  369.65  5402846.0   376.75
# 2330  2011-06-17  369.20  381.95  369.20  380.55  4624129.0   369.65
# 2331  2011-06-20  380.00  391.95  375.55  389.85  7974447.0   380.55
#
#         Return   SMA_5   SMA_10
# 2327  0.004502  377.03  378.420
# 2328 -0.006723  376.83  377.935
# 2329 -0.018845  375.45  376.785
# 2330  0.029487  376.77  376.995
# 2331  0.024438  379.22  377.980

# %%
df5.isna().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# Close_1    0
# Return     0
# SMA_5      0
# SMA_10     0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df5[["Open","High","Low","Volume"]])
plt.title("Box Plot For Outliers Detection")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
x=df5.drop(["Close"],axis="columns")

# %%
y=df5["Close"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.2,random_state=42)

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict=model.predict(x_test)
print("The R2 score of the model is",r2_score(y_test,y_predict))
# Out:
# The R2 score of the model is 0.9325273649645517

# %%
new_data=[[]]

# %%
print(model.feature_names_in_)
print(len(model.feature_names_in_))
# Out:
# ['Open' 'High' 'Low' 'Volume' 'Close_1' 'High_Low_Spread' 'Return' 'SMA_5'
#  'SMA_10']
# 9

# %%
new_data = np.array([[1850.5, 1865.0, 1842.0, 1857.0, 250000, 1845.5, 23.0, 11.5, 1850.0]])

# %%
prediction=model.predict(new_data)
print("Prediction is:",prediction[0])
# Out:
# Prediction is: 403.3434999999999
# c:\Users\codin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
new_data = np.array([[880.25, 885.90, 875.15, 882.10, 2000000, 879.50, 0.003, 880.10, 878.80]])

# Convert to DataFrame with correct feature names

# %%
prediction=model.predict(new_data)
print("Prediction is:",prediction[0])
# Out:
# Prediction is: 492.7165
# c:\Users\codin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
with open("model.pkl","wb") as file:
    pickle.dump(model,file)

# %%
df5.head(25)
# Out:
#             Date    Open    High     Low   Close      Volume  Close_1  \
# 2327  2011-06-14  377.95  380.50  377.00  379.30   2879443.0   377.60
# 2328  2011-06-15  377.95  379.40  375.10  376.75   2319378.0   379.30
# 2329  2011-06-16  375.00  379.80  367.65  369.65   5402846.0   376.75
# 2330  2011-06-17  369.20  381.95  369.20  380.55   4624129.0   369.65
# 2331  2011-06-20  380.00  391.95  375.55  389.85   7974447.0   380.55
# 2332  2011-06-21  390.05  398.40  388.15  391.60   5010285.0   389.85
# 2333  2011-06-22  393.00  395.00  377.60  381.80   7698165.0   391.60
# 2334  2011-06-23  380.15  387.10  379.30  382.15   2949962.0   381.80
# 2335  2011-06-24  383.55  394.25  383.55  391.90   4931183.0   382.15
# 2336  2011-06-27  389.00  398.90  388.00  396.00   4469968.0   391.90
# 2337  2011-06-28  396.80  404.95  396.25  400.30   9660772.0   396.00
# 2338  2011-06-29  401.55  403.95  399.45  401.45   3842334.0   400.30
# 2339  2011-06-30  402.00  403.80  389.75  394.90  11829151.0   401.45
# 2340  2011-07-01  394.90  396.00  382.35  383.45   5226738.0   394.90
# 2341  2011-07-04  385.50  388.30  383.00  384.30   3974708.0   383.45
# 2342  2011-07-05  386.00  386.40  378.25  382.25   2338180.0   384.30
# 2343  2011-07-06  380.55  388.80  380.55  383.40   3829322.0   382.25
# 2344  2011-07-07  383.55  398.90  383.55  398.00   8086735.0   383.40
# 2345  2011-07-08  399.85  409.90  395.65  398.15   5606368.0   398.00
# 2346  2011-07-11  398.05  399.90  389.75  391.25   1702731.0   398.15
# 2347  2011-07-12  387.10  394.70  385.25  386.90   2460319.0   391.25
# 2348  2011-07-13  387.10  397.30  386.40  394.90   5453915.0   386.90
# 2349  2011-07-14  395.80  399.10  393.65  396.55   3456859.0   394.90
# 2350  2011-07-15  398.25  398.50  391.30  392.95   1730730.0   396.55
# 2351  2011-07-18  390.30  395.50  390.15  393.10    975877.0   392.95
#
#         Return   SMA_5   SMA_10  High_Low_Spread
# 2327  0.004502  377.03  378.420             3.50
# 2328 -0.006723  376.83  377.935             4.30
# 2329 -0.018845  375.45  376.785            12.15
# 2330  0.029487  376.77  376.995            12.75
# 2331  0.024438  379.22  377.980            16.40
# 2332  0.004489  381.68  379.355            10.25
# 2333 -0.025026  382.69  379.760            17.40
# 2334  0.000917  385.19  380.320             7.80
# 2335  0.025514  387.46  382.115            10.70
# 2336  0.010462  388.69  383.955            10.90
# 2337  0.010859  390.43  386.055             8.70
# 2338  0.002873  394.36  388.525             4.50
# 2339 -0.016316  396.91  391.050            14.05
# 2340 -0.028995  395.22  391.340            13.65
# 2341  0.002217  392.88  390.785             5.30
# 2342 -0.005334  389.27  389.850             8.15
# 2343  0.003009  385.66  390.010             8.25
# 2344  0.038080  386.28  391.595            15.35
# 2345  0.000377  389.22  392.220            14.25
# 2346 -0.017330  390.61  391.745            10.15
# 2347 -0.011118  391.54  390.405             9.45
# 2348  0.020677  393.84  389.750            10.90
# 2349  0.004178  393.55  389.915             5.45
# 2350 -0.009078  392.51  390.865             7.20
# 2351  0.000382  392.88  391.745             5.35
